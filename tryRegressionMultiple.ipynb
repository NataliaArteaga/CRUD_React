# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaArteaga/CRUD_React/blob/master/tryRegressionMultiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm
from scipy import stats


X = datos.iloc[:,[1,2,3,4,5,6]]
y = datos.CLL

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())



import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import csv
import pylab as pl

datos = pd.read_csv('./datosTesisCorrected.csv')
datos.describe()
cda= datos[['CLL','NDVI','CVI','GNDVI', 'NRVI', 'RVI', 'GCI']]
cda.head(6)
viz=cda[['CLL','NDVI','CVI','GNDVI', 'NRVI', 'RVI', 'GCI']]
viz.hist()
plt.show()

plt.scatter(cda.NDVI,cda.CLL, color='green')
plt.xlabel('NDVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.NDVI,cda.CLL, color='blue')
plt.xlabel('CVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.NDVI,cda.CLL, color='red')
plt.xlabel('GNDVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.NDVI,cda.CLL, color='yellow')
plt.xlabel('NRVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.NDVI,cda.CLL, color='purple')
plt.xlabel('RVI')
plt.ylabel('CLL')
plt.show

plt.scatter(cda.NDVI,cda.CLL, color='orange')
plt.xlabel('GCI')
plt.ylabel('CLL')
plt.show



msk = np.random.rand(len(datos)) < 0.8
entreno = cda[msk]
test = cda[~msk]


plt.scatter(entreno.NDVI,entreno.CLL, color='magenta')
plt.xlabel('NDVI')
plt.ylabel('CLL')
plt.show

from sklearn import linear_model
regr = linear_model.LinearRegression ()
x = np.asanyarray(entreno[['NDVI','CVI','GNDVI', 'NRVI', 'RVI', 'GCI']])
y = np.asanyarray(entreno[['CLL']])

regr.fit(x,y)

print('coeficientes', regr.coef_)

y_hat = regr.predict(test[['NDVI','CVI','GNDVI', 'NRVI', 'RVI', 'GCI']])
x = np.asanyarray(test[['NDVI','CVI','GNDVI', 'NRVI', 'RVI', 'GCI']])
y = np.asanyarray(test[['CLL']])

from sklearn.metrics import r2_score
print("Suma residual de cuadrados: %.2f" % np.mean((y_hat - y)**2))
print("Varianza modelo: %.2f" % regr.score(x,y))
print("r2: %.2f" % r2_score(y,y_hat ))
